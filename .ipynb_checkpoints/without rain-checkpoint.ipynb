# %%
import pandas as pd

# %%
df = pd.read_csv('open_mateo_train_test.csv')

# %%
df.columns
# Out:
# Index(['date', 'spoke', 'weather_code', 'working_precipitation', 'rain_sum',
#        'showers_sum', 'precipitation_hours', 'year', 'month', 'day', 'weekday',
#        'hour', 'net', 'discount', 'total_item_qty', 'total_transaction_qty',
#        'transaction_mean_price'],
#       dtype='object')

# %%
threshold = df['working_precipitation'].quantile(0.8)
df = df[df['working_precipitation'] < threshold]
df.shape
# Out:
# (1450, 17)

# %%
# Drop rows where working_precipitation is zero
df = df[df['weather_code'].isin([0, 1, 2, 3,45,61,80])]
df.shape

# threshold = df['working_precipitation'].quantile(0.8)
# df = df[df['working_precipitation'] < threshold]
# df.shape
# Out:
# (1106, 17)

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt


# Group the data by 'spoke'
grouped = df.groupby('spoke')

# Initialize a dictionary to store regression results
regression_results = {}

# Iterate over each group (spoke)
for spoke, group in grouped:
    # Prepare X (discount) and y (net)
    X = group['discount'].values.reshape(-1, 1)  # Independent variable
    y = group['net'].values                      # Dependent variable

    # Fit the linear regression model
    model = LinearRegression()
    model.fit(X, y)

    # Store the results
    regression_results[spoke] = {
        'slope': model.coef_[0],
        'intercept': model.intercept_,
        'r_squared': model.score(X, y)  # Optional: R-squared value
    }

    # Optional: Plot the regression line for each spoke
    plt.scatter(X, y, label=f'Spoke {spoke} Data')
    plt.plot(X, model.predict(X), label=f'Spoke {spoke} Regression Line')

# Add labels and legend to the plot
plt.xlabel('Discount')
plt.ylabel('Net')
plt.title('Linear Regression: Net vs Discount for Each Spoke')
plt.legend()
plt.show()

# Print the regression formulas for each spoke
for spoke, results in regression_results.items():
    print(f"Spoke {spoke}: Net = {results['slope']:.2f} * Discount + {results['intercept']:.2f}")
# Out:
# Spoke commonwealth: Net = 4.74 * Discount + 34429.68
# Spoke makati: Net = 1.11 * Discount + 53908.52
# Spoke malate: Net = 2.93 * Discount + 36843.14

# %%
import pandas as pd

# Define the regression formulas for each spoke
def calculate_net(spoke, discount):
    if spoke == 'commonwealth':
        return 4.74 * discount + 34429.68
    elif spoke == 'makati':
        return 1.11 * discount + 53908.52
    elif spoke == 'malate':
        return 2.930 * discount + 36843.14
    else:
        return None  # Handle other spokes if needed

# Compute baseline net income (discount = 0)
df['baseline_net'] = df['spoke'].apply(lambda x: calculate_net(x, 0))

# Compute current net income using actual discount values
df['current_net'] = df.apply(lambda row: calculate_net(row['spoke'], row['discount']), axis=1)

# Compute the impact of discounts
df['discount_impact'] = df['current_net'] - df['baseline_net']

# Display the updated DataFrame
print(df[['spoke', 'discount', 'net', 'baseline_net', 'current_net', 'discount_impact']])
# Out:
#              spoke  discount       net  baseline_net  current_net  \
# 0     commonwealth     82.86  27542.97      34429.68   34822.4364
# 1     commonwealth     35.54  25764.44      34429.68   34598.1396
# 2     commonwealth      0.00  11044.65      34429.68   34429.6800
# 3     commonwealth      0.00  32642.83      34429.68   34429.6800
# 4     commonwealth    223.43  38926.40      34429.68   35488.7382
# ...            ...       ...       ...           ...          ...
# 1800        malate    940.00  39885.73      36843.14   39597.3400
# 1803        malate   1223.70  31074.37      36843.14   40428.5810
# 1810        malate   1385.68  24480.62      36843.14   40903.1824
# 1811        malate     50.00  21056.26      36843.14   36989.6400
# 1812        malate    685.00  26687.49      36843.14   38850.1900
#
#       discount_impact
# 0            392.7564
# 1            168.4596
# 2              0.0000
# 3              0.0000
# 4           1059.0582
# ...               ...
# 1800        2754.2000
# 1803        3585.4410
# 1810        4060.0424
# 1811         146.5000
# 1812        2007.0500
#
# [1106 rows x 6 columns]

# %%
# Calculate percentage earned
df['percentage_earned'] = (df['discount_impact'] / df['baseline_net']) * 100


# Calculate the overall average percentage earned
average_percentage_earned = df['percentage_earned'].mean()

# Calculate the average percentage earned for each spoke
average_percentage_by_spoke = df.groupby('spoke')['percentage_earned'].mean()

# Display the results
print(f"Overall Average Percentage Earned: {average_percentage_earned:.2f}%")
print("\nAverage Percentage Earned by Spoke:")
print(average_percentage_by_spoke)
# Out:
# Overall Average Percentage Earned: 7.10%
#
# Average Percentage Earned by Spoke:
# spoke
# commonwealth    20.847302
# makati           3.262881
# malate           5.061085
# Name: percentage_earned, dtype: float64

# %%
df.describe()
# Out:
#        weather_code  working_precipitation     rain_sum  showers_sum  \
# count   1813.000000            1813.000000  1813.000000  1813.000000
# mean      51.872587               6.155709     0.845891     5.301600
# std       42.052944              12.203017     7.527198     8.297484
# min        1.000000               0.000000     0.000000     0.000000
# 25%        3.000000               0.000000     0.000000     0.000000
# 50%       80.000000               1.000000     0.000000     0.900000
# 75%       95.000000               8.599999     0.000000     8.200000
# max       96.000000             236.099990   225.300000    90.700000
#
#        precipitation_hours         year        month          day    hour  \
# count          1813.000000  1813.000000  1813.000000  1813.000000  1813.0
# mean              6.666299  2023.387755     6.351903    15.778820    16.0
# std               7.131186     0.672877     3.260362     8.761631     0.0
# min               0.000000  2022.000000     1.000000     1.000000    16.0
# 25%               0.000000  2023.000000     4.000000     8.000000    16.0
# 50%               5.000000  2023.000000     7.000000    16.000000    16.0
# 75%              12.000000  2024.000000     9.000000    23.000000    16.0
# max              24.000000  2024.000000    12.000000    31.000000    16.0
#
#                  net      discount  total_item_qty  total_transaction_qty  \
# count    1813.000000   1813.000000     1813.000000            1813.000000
# mean    45833.565323   1429.495301      189.174297              87.456702
# std     23758.109934   2276.126608       83.208941              33.172286
# min      1845.540000      0.000000        9.000000               6.000000
# 25%     31967.720000     74.860000      137.000000              68.000000
# 50%     43322.330000    668.090000      181.000000              86.000000
# 75%     55592.360000   1870.000000      233.000000             104.000000
# max    229600.810000  37606.140000      700.000000             287.000000
#
#        transaction_mean_price
# count             1813.000000
# mean               510.483796
# std                 83.751630
# min                210.430000
# 25%                454.462222
# 50%                499.837021
# 75%                550.078396
# max               1121.932826

# %%
df_no_rain = df[df['working_precipitation']==0]

# %%
df_no_rain
# Out:
#             date         spoke  weather_code  working_precipitation  rain_sum  \
# 0     2023-12-28  commonwealth          45.0                    0.0       0.0
# 1     2023-12-29  commonwealth          45.0                    0.0       0.0
# 2     2023-12-30  commonwealth           2.0                    0.0       0.0
# 4     2024-01-03  commonwealth          45.0                    0.0       0.0
# 5     2024-01-04  commonwealth           3.0                    0.0       0.0
# ...          ...           ...           ...                    ...       ...
# 1653  2024-05-22        malate           2.0                    0.0       0.0
# 1661  2024-05-30        malate           3.0                    0.0       0.0
# 1720  2024-07-29        malate          45.0                    0.0       0.0
# 1760  2024-09-07        malate          45.0                    0.0       0.0
# 1784  2024-10-01        malate          45.0                    0.0       0.0
#
#       showers_sum  precipitation_hours  year  month  day    weekday  hour  \
# 0             0.0                  0.0  2023     12   28   Thursday    16
# 1             0.0                  0.0  2023     12   29     Friday    16
# 22                457.085955
# ...                      ...
# 1808              507.556329
# 1809              467.871034
# 1810              480.012157
# 1811              438.672083
# 1812              503.537547
#
# [1205 rows x 17 columns]

# %%
df_no_rain.describe()
# Out:
#        weather_code  working_precipitation  rain_sum  showers_sum  \
# count    608.000000                  608.0     608.0        608.0
# mean       5.271382                    0.0       0.0          0.0
# std       10.133558                    0.0       0.0          0.0
# min        1.000000                    0.0       0.0          0.0
# 25%        2.000000                    0.0       0.0          0.0
# 50%        3.000000                    0.0       0.0          0.0
# 75%        3.000000                    0.0       0.0          0.0
# max       45.000000                    0.0       0.0          0.0
#
#        precipitation_hours         year       month         day   hour  \
# count                608.0   608.000000  608.000000  608.000000  608.0
# mean                   0.0  2023.486842    4.424342   15.203947   16.0
# std                    0.0     0.615418    3.560380    9.043799    0.0
# min                    0.0  2022.000000    1.000000    1.000000   16.0
# 25%                    0.0  2023.000000    2.000000    7.000000   16.0
# 50%                    0.0  2024.000000    3.000000   15.000000   16.0
# 75%                    0.0  2024.000000    5.000000   23.000000   16.0
# max                    0.0  2024.000000   12.000000   31.000000   16.0
#
#                  net      discount  total_item_qty  total_transaction_qty  \
# count     608.000000    608.000000      608.000000             608.000000
# mean    45802.595329   1048.598635      187.810855              86.475329
# std     27913.183623   1812.216728       88.854909              35.890682
# min      1845.540000      0.000000       11.000000               6.000000
# 25%     30937.485000     71.430000      136.000000              68.000000
# 50%     41072.095000    354.715000      173.000000              84.000000
# 75%     52779.677500   1202.500000      224.000000             101.000000
# max    229600.810000  11300.000000      700.000000             284.000000
#
#        transaction_mean_price
# count              608.000000
# mean               512.987511
# std                 87.485081
# min                307.590000
# 25%                456.202882
# 50%                497.308336
# 75%                548.377118
# max               1023.596429

# %%
df_with_rain.describe()
# Out:
#        weather_code  working_precipitation     rain_sum  showers_sum  \
# count   1205.000000            1205.000000  1205.000000  1205.000000
# mean      75.385892               9.261660     1.272697     7.976598
# std       30.979411              13.975779     9.204715     9.069749
# min        2.000000               0.100000     0.000000     0.000000
# 25%       80.000000               1.000000     0.000000     0.900000
# 50%       95.000000               5.400000     0.000000     5.200000
# 75%       95.000000              12.900001     0.000000    12.100000
# max       96.000000             236.099990   225.300000    90.700000
#
#        precipitation_hours         year        month          day    hour  \
# count          1205.000000  1205.000000  1205.000000  1205.000000  1205.0
# mean             10.029876  2023.337759     7.324481    16.068880    16.0
# std               6.539868     0.694982     2.604642     8.604994     0.0
# min               1.000000  2022.000000     1.000000     1.000000    16.0
# 25%               5.000000  2023.000000     6.000000     9.000000    16.0
# 50%               9.000000  2023.000000     8.000000    16.000000    16.0
# 75%              14.000000  2024.000000     9.000000    23.000000    16.0
# max              24.000000  2024.000000    12.000000    31.000000    16.0
#
#                  net      discount  total_item_qty  total_transaction_qty  \
# count    1205.000000   1205.000000     1205.000000            1205.000000
# mean    45849.191676   1621.682166      189.862241              87.951867
# std     21369.961395   2455.811975       80.239007              31.716445
# min      2200.900000      0.000000        9.000000               7.000000
# 25%     33037.530000     81.000000      137.000000              69.000000
# 50%     44606.070000    857.260000      187.000000              88.000000
# 75%     56454.730000   2171.150000      238.000000             106.000000
# max    209955.440000  37606.140000      662.000000             287.000000
#
#        transaction_mean_price
# count             1205.000000
# mean               509.220510
# std                 81.811318
# min                210.430000
# 25%                454.202800
# 50%                501.675618
# 75%                552.076642
# max               1121.932826
